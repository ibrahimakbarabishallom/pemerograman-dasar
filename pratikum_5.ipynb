# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrahimakbarabishallom/pemerograman-dasar/blob/main/pratikum_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nilai = 0
while nilai < 10:
    print("Hello Polibatam!")
    nilai = nilai + 1
else:
    print("Perulangan WHILE selesai hingga akhir")
# Out:
# Hello Polibatam!
# Hello Polibatam!
# Hello Polibatam!
# Hello Polibatam!
# Hello Polibatam!
# Hello Polibatam!
# Hello Polibatam!
# Hello Polibatam!
# Hello Polibatam!
# Hello Polibatam!
# Perulangan WHILE selesai hingga akhir
