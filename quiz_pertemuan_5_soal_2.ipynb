# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrahimakbarabishallom/pemerograman-dasar/blob/main/quiz_pertemuan_5_soal_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program menampilkan nama "Ibrahim" sebanyak 200 kali

for i in range(200):
    print("Ibrahim")
# Out:
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# Ibrahim
# ...
